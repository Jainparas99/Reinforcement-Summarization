# %%
import os
import random
import numpy as np
import torch
import torch.nn.functional as F
from datasets import load_dataset
from transformers import T5ForConditionalGeneration, T5Tokenizer, AdamW
from rouge_score import rouge_scorer
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
import spacy

# Set random seeds for reproducibility
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

# Reward calculation utilities
class RewardCalculator:
    def __init__(self):
        self.rouge_scorer = rouge_scorer.RougeScorer(["rouge1", "rougeL"], use_stemmer=True)
        self.semantic_model = SentenceTransformer("paraphrase-MiniLM-L6-v2")
        self.nlp = spacy.load("en_core_web_sm")

    def length_reward(self, generated_summary, reference_summary):
        """Reward based on summary length similarity."""
        gen_length = len(generated_summary.split())
        ref_length = len(reference_summary.split())
        return max(0, 1 - abs(gen_length - ref_length) / ref_length)

    def keyword_coverage(self, generated_summary, reference_summary):
        """Compute keyword coverage reward."""
        vectorizer = CountVectorizer(stop_words='english', max_features=5)
        vectorizer.fit([reference_summary])
        keywords = set(vectorizer.get_feature_names_out())
        gen_words = set(generated_summary.split())
        return len(keywords & gen_words) / len(keywords) if keywords else 0

    def entity_coverage(self, generated_summary, reference_summary):
        """Compute entity coverage reward."""
        ref_doc = self.nlp(reference_summary)
        gen_doc = self.nlp(generated_summary)

        ref_entities = {ent.text for ent in ref_doc.ents}
        gen_entities = {ent.text for ent in gen_doc.ents}

        return len(ref_entities & gen_entities) / len(ref_entities) if ref_entities else 1

    def calculate_reward(self, generated_summary, reference_summary):
        """Calculate comprehensive reward."""
        # ROUGE score
        rouge_scores = self.rouge_scorer.score(generated_summary, reference_summary)
        rouge_reward = rouge_scores["rouge1"].fmeasure + rouge_scores["rougeL"].fmeasure

        # Semantic similarity
        generated_embedding = self.semantic_model.encode([generated_summary])
        reference_embedding = self.semantic_model.encode([reference_summary])
        semantic_reward = cosine_similarity(generated_embedding, reference_embedding)[0][0]

        # Additional rewards
        length_penalty = self.length_reward(generated_summary, reference_summary)
        keyword_cov = self.keyword_coverage(generated_summary, reference_summary)
        entity_cov = self.entity_coverage(generated_summary, reference_summary)

        # Weighted combined reward
        return (0.4 * rouge_reward + 
                0.3 * semantic_reward + 
                0.1 * length_penalty + 
                0.1 * keyword_cov + 
                0.1 * entity_cov)

class T5RLTrainer:
    def __init__(self, model, tokenizer, dataset, lr=5e-5):
        self.model = model
        self.tokenizer = tokenizer
        self.dataset = dataset
        self.reward_calculator = RewardCalculator()
        
        # Optimizer
        self.optimizer = AdamW(self.model.parameters(), lr=lr)

    def generate_summary(self, input_ids, max_length=150):
        """Generate summary using the model."""
        outputs = self.model.generate(
            input_ids, 
            max_length=max_length, 
            num_return_sequences=1, 
            do_sample=True
        )
        return self.tokenizer.decode(outputs[0], skip_special_tokens=True)

    def policy_gradient_update(self, input_ids, reference_summary):
        """Perform policy gradient update."""
        # Ensure model is in training mode
        self.model.train()

        # Generate summary
        generated_summary = self.generate_summary(input_ids)

        # Calculate reward
        reward = self.reward_calculator.calculate_reward(generated_summary, reference_summary)

        # Compute log probabilities for the generated summary
        outputs = self.model(input_ids=input_ids, labels=self.tokenizer(generated_summary, return_tensors='pt').input_ids)
        log_probs = outputs.loss  # This is the negative log-likelihood

        # Policy gradient update (simplified version)
        policy_loss = log_probs * reward

        # Zero gradients, backpropagate, and optimize
        self.optimizer.zero_grad()
        policy_loss.backward()
        self.optimizer.step()

        return reward, generated_summary

    def train(self, num_epochs=3, batch_size=8):
        print("Starting RL Training...")
        
        # Shuffle dataset
        indices = list(range(len(self.dataset)))
        random.shuffle(indices)

        total_rewards = []
        for epoch in range(num_epochs):
            epoch_rewards = []
            
            for i in range(0, len(indices), batch_size):
                batch_indices = indices[i:i+batch_size]
                
                for idx in batch_indices:
                    # Prepare input
                    article = self.dataset[idx]['article']
                    reference_summary = self.dataset[idx]['highlights']
                    
                    # Tokenize input
                    input_ids = self.tokenizer(
                        article, 
                        return_tensors='pt', 
                        truncation=True, 
                        max_length=512
                    ).input_ids
                    
                    # RL update
                    reward, generated_summary = self.policy_gradient_update(input_ids, reference_summary)
                    
                    epoch_rewards.append(reward)
                    
                    print(f"Epoch {epoch+1}, Sample {i+batch_indices.index(idx)+1}")
                    print(f"Generated Summary: {generated_summary}")
                    print(f"Reward: {reward}\n")
            
            # Compute and store average reward for the epoch
            avg_reward = np.mean(epoch_rewards)
            total_rewards.append(avg_reward)
            print(f"Epoch {epoch+1} Average Reward: {avg_reward}")
        
        return total_rewards

def main():
    # Set random seed
    set_seed(42)

    # Set CUDA device
    os.environ["CUDA_VISIBLE_DEVICES"] = "14"

    # Load dataset
    dataset = load_dataset("cnn_dailymail", "3.0.0", cache_dir="./datasets/cnn_dailymail_clean")

    # Load pre-trained T5 model
    model = T5ForConditionalGeneration.from_pretrained("./summarization_model")
    tokenizer = T5Tokenizer.from_pretrained("./summarization_model")

    # Create RL trainer
    rl_trainer = T5RLTrainer(model, tokenizer, dataset['train'])

    # Train with RL
    rewards = rl_trainer.train(num_epochs=1, batch_size=8)

    # Save the RL-fine-tuned model
    model.save_pretrained("./t5_rl_summarization_model")
    tokenizer.save_pretrained("./t5_rl_summarization_model")

    print("RL Training Complete. Rewards:", rewards)

if __name__ == "__main__":
    main()
# Out:
# /home/stu15/s15/pj2196/miniconda3/envs/idai610/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /home/stu15/s15/pj2196/miniconda3/envs/idai610/lib/python3.10/site-packages/transformers/optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Starting RL Training...
# Epoch 1, Sample 1
# Generated Summary: British mercenary Simon Mann jailed for 34 years after he landed against Zimbabwe. Mann testified that his former British army commander was in charge of the plot. He was convicted earlier this year of trying to overthrow a Nigeria coup in 2004. The case of Abu Maasutid Suttera is dragged from prison after his imprisonment.
# Reward: 0.6561788112367378
#
# Epoch 1, Sample 2
# Generated Summary: Thousands more killed and wounded more than 200 in Jaipur attack. Authorities impose curfew in Rajasthan following earlier attacks against Islamic militant groups. No one has claimed responsibility for the attack, the chief minister says. A government that has called for'strong, vigilante" coalition on Muslims.
# Reward: 0.4877215328778456
#
# Epoch 1, Sample 3
# Generated Summary: NEW: U.S., European, Russian foreign policy chief calls for ceasefire. The Russian Foreign Minister: The Russian foreign minister says he supports Georgia ''Anita's territorial integrity' Russian official: "We urge all parties, Georgians, South Ossetians and Russians to avoid conflict" U.S., the European Union, the OSCE deploying envoys to order. Russia's foreign ministry, France, Russia's state minister, says.
# Generated Summary: The Large Hadron Collider is a device aimed at 'clearing' Universe theories. Experts gathered in France for the second time in order to capture particles and accelerate. Sceptics claim the Big Bang experiment could lead to a finding of a black hole. The collider will operate at higher intensities and generate data by 2009, experts have predicted.
# Reward: 0.3934133989029085
#
# Epoch 1, Sample 36
# Generated Summary: "Medical tourism" has become major players in developing world of pros. Southwest is now making its way to countries where doctors can do cosmetic surgeries abroad. The biggest stars of surgery overseas are South Africa, Argentina, Thailand and Brazil.
# Reward: 0.41559758416321724
#
# Epoch 1, Sample 37
# Generated Summary: British junk dealer said it was "small and shiny" while gold cup was sold under a bed. The 512-inch gold cup, which experts have dated to the third or fourth century B.C., fetched $100,000 at a Boursemouth in southern England. He called the body's name a Roman god, godlines and gods of gates and doors.
# Reward: 0.6449091263166687
#
# Epoch 1, Sample 38
# Generated Summary: NEW: Ex-King Gyanendra quit the government on Wednesday after joining the Opposition. The National National flag is fluttering on the royal palace. New government transforms deposed king's opulent palace. He will live outside Nepal, a civilian in a summer palace.
# Reward: 0.5264937462549255
#
# Epoch 1, Sample 39
# Generated Summary: NEW: China suspended exports of aqua dots beads that are contaminated with substance. 5.0 million of the beads are recalled in future. Korean kids in Australia swallowed beads and were hospitalized following ingesting. The products shipped to Australia by the U.S. Chemical products company, company says.
# Reward: 0.6056758927504222
#
# Epoch 1, Sample 40
# Generated Summary: Robert McCarthy reconstructed Neanderthal vocal tracts to simulate their voice. McCarthy teamed with linguist Phil Lieberman for his vocal simulation, U.S. anthropologist: "They would have spoken a bit differently" He says Neanderthal lacked the "Qualal vowels" modern humans use.
# Reward: 0.6489982597033184
#
# Epoch 1, Sample 41
# Generated Summary: NEW: 145 students on refugee list to 400,000 Iraqi students, some say. Jordanian minister of education says he expects Jordan to accommodate Iraqi students this year. Jordan says influx is putting a strain on school. Jordan has been given aid to Jordan, a move in Iraq since war began.
# Reward: 0.6510181062117868
#
# Epoch 1, Sample 42
# Generated Summary: Man calls for Bush to meet Muslim Palestine, Muslim-U.S. President George Bush. Adam Yahiye Gadahn's record "invitation to face life and repentance" Gadahn, who was arrested in 2001, calls for "imminent appeal" to U.S. President Bush urging Bush to visit the region with "liberty" Gadahn is a self-proclaimed al Qaeda military person who fought in terrorism.
# Reward: 0.5335962658318676
#
# Epoch 1, Sample 43
# Generated Summary: O.S. general. Iraqis condemn U.S. soldier's desecration of Qurans. The Taliban' is decrying the U.S. for this action. U.S. Navy says it says it "cant be justified"
# Reward: 0.47239053575888923
#
# Epoch 1, Sample 44
# Generated Summary: New state arrests suspect Chinese company paying in cash and money. Three Thai nationals accused of importing counterfeit luxury bags in the United States arrested Wednesday. Three Chinese citizens arrested in Mexico; three others are. Alleged leaders of counterfeit business are Chinese citizens in New York, in New York.
# Reward: 0.621691267882166
#
# Epoch 1, Sample 45
# Generated Summary: NEW: "Anything just got real dark," another resident iReporter says. A tornado swept through Tupelo, Mississippi, on Thursday; no injuries reported. Police officers assessing damages from tropical storm. A tornado strikes to furniture market, killing 17 people.
# Reward: 0.5815051394060762
#
# Epoch 1, Sample 46
# Generated Summary: Apple and T-Mobile says they can buy your iPhone when a user is unsure about whether software is legal. Apple-owned software maker Brett Schulte: "We don't want to be hounded" The developers said they're not enrolled to pay the bill owed because they don't have all the data they need. An AT&T spokesman: Apple says they're expecting the legality of unlocking the world's iPhone.
# Reward: 0.4108909792425608
#
# Epoch 1, Sample 47
# Generated Summary: NEW: Military: Black Hawk helicopter crashed Thursday. Russian Air Base halted on Wednesday as a precaution. Black Hawk helicopter crashed near a major highway, police said.
# Reward: 0.4372500066787192
#
# Epoch 1, Sample 48
# Generated Summary: NEW: U.S. officials say in July 2013 that the idling of the U.S. military is growing among U.S. Iran comes without responsibility for the illegal export of Russian weapons and military technology to Iran, in a press conference. "China and Iran pose a particular Export control concerns," the Justice Department says Thursday.
# Reward: 0.46452660395789813
#
# Epoch 1, Sample 49
# Generated Summary: Jailed "an inspiration." The Bill-backed batsmen died Sunday in the Irish match on Tuesday. James McGrath died Sunday at the age of 42 from a long battle with cancer. The one-day international against West Indies are to be held on Tuesday.
# Reward: 0.5552150480910202
#
# Epoch 1, Sample 50
# Generated Summary: Officials: About 300,000 people are still trapped by the flooding this month. The Grijalva River pushed over its banks through the state capital of Villahermosa on Thursday. The floods follow weeks of rain in the largely swampy state of Tabasco. Government officials say about 800,000 people are still trapped by the flooding in Tabasco.
# Reward: 0.5521604120477718
#
# Epoch 1, Sample 51
# Generated Summary: NEW: "This has become very special," one affidavit says. NEW: "It was my understanding that Western Precision was paying $170,000 into Jeffs' homes" NEW: T.S. state branch: "Very little can ever get some" new FBI personnel, he says. Jeffs sect: "We need our children"
# Reward: 0.3419701123139737
#
# Epoch 1, Sample 52
# Generated Summary: NEW: Mueller rejects whether his side will benefit from the GOP vote, and says, Obama's bid will go out "instead to America" Obama "has tried to enlighten the federal government-level policies," said Robert Reich. Reich, a former Clinton spokesman, has since endorsed Barack Obama. Reich says: "Where I would have I's the Obamas to be"
# Reward: 0.46782206635849144
#
# Epoch 1, Sample 53
# Generated Summary: A potentially dangerous outbreak of colony collapses suggests the disease is playing a role in colonies. The colony could lead to a new treatment for colony collapse. New tests show that bees in Australia have resistant to colony collapse. CDC: There are many strong strains on the world's colony in.
# Reward: 0.532502740678333
#
# Epoch 1, Sample 54
# Generated Summary: Rock group R.E.M. says R.E.M. honored to have part of the film project after R.E.M. worked on track's upcoming album. Song, "Back to the Day Is Done" aired in studio Wednesday. R.E.M. singer Michael Stipe says Is "Planet in Peril," features Mitchell Cooper, "Hauna" director.
# Reward: 0.5907621267021343
#
# Epoch 1, Sample 55
# Generated Summary: Ajax held to a 2-2 draw at Vitesse of Arningen on Sunday. Heracles are held 1-1 by Sparta Rotterdam during the season at the defeat. Heracles can beat Nijmegen 1-0 in a 5-0 victory at their home.
# Reward: 0.5543610621952428
#
# Epoch 1, Sample 56
# Generated Summary: NEW: Witnesses say at least six died in the blast -- and 18, among the wounded. A suicide car bomber drove up near embassy near the Danish Embassy, police say. "It is terrible that terrorists," Danish diplomat says; No embassy official was seriously hurt. Danish minister: "My immediate reaction is that you can only condemn"
# Reward: 0.5819534400147868
#
# Epoch 1, Sample 57
# Generated Summary: Turkey lost 2-0 to Portugal in their opening game of the match in July, unable to play at World Cup. At the top of the table table, Turkey play Switzerland, who lost 1-0 to the Czech Republic. The Reds play Baran Lucos, and Garn's Peteros de Saffros, a 1-0 defender, is expected to come together with a group game in May. Turkey coach Kevin Gauntuk says the injury could be a problem because of 'wholen a "dosne Belgium"
# Reward: 0.30834937254587813
#
# Epoch 1, Sample 58
# Generated Summary: NEW: US President: U.S. Senate GOP lawmakers would use supplemental spending bill for war. Bush signs bill that would fund wars across the country. Senate committee says bill should go into effect after shutdown. White House says presidents, Democrats will play key key events in the Senate.
# Reward: 0.5713613610477238
#
# Epoch 1, Sample 59
# Generated Summary: NEW: Thousands of lib Dems will vote for candidate under new leadership -- it said. Lib Dem A. is a prominent leader of Lebanon's anti-Silbanese. The anti-Selse election will be held at the French-led meeting on Sunday. Lebanese voters and opponents of Lebanon's pro-Israel Party party are splitting seats, LBC reports.
# Reward: 0.358364917692684
#
# Epoch 1, Sample 60
# Generated Summary: John Webber of England sells bronze artifact, gold cup as well as two others for auction. The gold cup, in 1850s BC, fetches $100,000 at auction in Dorchester. "It was made from a plastic cup in medieval England," Webber tells charity. Webber spent years researching the antique, he claims, but gave it elsewhere.
# Reward: 0.5254709809556954
#
# Epoch 1, Sample 61
# Generated Summary: a panel separated from a Boeing 757 earlier this week in an incident. The wing panel then struck windows, cracking the wings and causing a branch to collapse. The aircraft landed in Philadelphia, PA.. 10minutes later, and none of the 174 passengers aboard were injured, a federal.
# Reward: 0.5370988730400327
#
# Epoch 1, Sample 62
# Generated Summary: NEW: Dallas's grand jury has upgraded charges since Wednesday; a grand jury has now upgraded the charges. Two-year-old Riley Ann Sawyers was moved from Ohio to Texas, and his mother died earlier in July at age 8. "Baby Grace" had a daughter who has been beaten to death by the girl. Prosecutors: Court charged couple of different parents over the deaths of her child.
# Reward: 0.7601618847138992
#
# Epoch 1, Sample 63
# Generated Summary: NEW: Sheriff's defying regulations at Texas border centers drew four restrictions. The Department of Homeland Security will bypass laws to build border fence between the United States and Mexico. An environmental group says the waivers "threatens the livelihoods and ecology of the entire Mexico border region," her colleague says. Those orders say the waivers are unconstitutional and not an exhaustive basis for the waivers.
# Reward: 0.5531001183360514
#
# Epoch 1, Sample 64
# Generated Summary: Silver bulletin says British teacher was allowed to be 'in and unintentional' 'Mohammed' Teacher sat sent by British teacher, a source says. Despite a jail sentence, other government officials said British official opened the school. U.N. agency says U.S. is investigating the question pending its 'homonymous' teddy bear "Mohammed" The government's secretary denies the claims against the Sudanese rebel.
# Reward: 0.3919759535014754
#
# Epoch 1, Sample 65
# Generated Summary: Officers have found body; "It is my sad duty to report that dead bodies are located today," FBI official says. Police say three bodies found drew a response Monday for missing children, police say. The FBI says Eddie Harrington threatened to kill kids and their children. Harrington says he allegedly kidnapped children, including daughters and children, a Georgian.
# Reward: 0.4664744622177549
#
# Epoch 1, Sample 66
# Reward: 0.41843389141778087
#
# Epoch 1, Sample 107
# Generated Summary: Ike is expected to make landfall. iReporter: "Somebody's panicking" and gas lines a tad ridiculous. "The lines were a tad ridiculous," iReporter says. "It was causing paranoia more than anything." Some gas stations in Ohio and Texas, including California, aren't at a gas station for about 35 days.
# Reward: 0.45153958255507387
#
# Epoch 1, Sample 108
# Generated Summary: Kimi Raikkonen lambass McLaren's Lewis Hamilton for the pit-lane accident. McLaren's Kimi Raikkonen bowed a fine of 10-place grid penalty for the crash. Raikkonen said there was a "serious mistake" before Hamilton had vowed to start winning again.
# Reward: 0.7782116599127976
#
# Epoch 1, Sample 109
# Generated Summary: A man who shot a co-worker from a crocodile in Northern Territory accidentally shot him, police say. The two men were on an animal farm in Australia in the Northern Territory, Queensland, when the crocodile grabbed the crocodile. Police: A man who shot the crocodile causing it to let go of a crocodile, a local news agency says.
# Reward: 0.7749662220694804
#
# Epoch 1, Sample 110
# Generated Summary: NEW: WGA members "voted, and we can go back to work," wrote of the convention. The strike was part of that fight over new media, the TV and DVDs. "It is not that we hoped for, and it is not all we deserve," said Writers Guild president who hasn't stepped up until after a full-year strike. The award: Splint is a long-term deal.
# Reward: 0.3790907038127218
#
# Epoch 1, Sample 111
# Generated Summary: NEW: Senate overrides President Bush's veto on a big bill that stops cuts in payments to doctors. The Senate voted to stop planned care cuts in Medicare to doctors following Bush's objections. The bill will be part of the proposed Medicare Advantage formula through July 1. Congress opposes GOP action.
# Reward: 0.699231085955597
#
# Epoch 1, Sample 112
# Generated Summary: Pastor Brady Boyd: Pastor calls it "highlight" and shows parents of the victims as they plan to protect their son. Three sisters were wounded in the December 9 rampage in New Life churches. Murray family says it felt "extremely emotional" for the Murrays -- they have known the man, Matthew Murray -- the girl who killed them. Boyd recommends visit: the Murrays visit New Life Church in Colorado, "highlight of my ministry""
# Reward: 0.47374133673566393
#
# Epoch 1, Sample 113
# Generated Summary: Newarkville, Georgia, reports tornadoes, stormy quake break, accountations "wonder to the Georgia" NEW: Two deaths, storms. NEW: One person seriously injured. Three people killed at high-speed bridges in Newtown, Ohio, Newtown, Newmont, North Carolina. Residents reported seeing a tornado touch down in Tennessee; one woman was seriously injured, weather service says.
# Reward: 0.45725783149131033
#
# Epoch 1, Sample 114
# Generated Summary: "It was the day of dreams," the boy said. Youssif, an Iraqi boy, met the local-yy boy in his game show -- It had the arousing him. "I want to see him again." It happened in the wake of the boy's death in Baghdad.
# Reward: 0.38479117955480313
#
# Epoch 1, Sample 115
# Generated Summary: Steven Spielberg, Steven Spielberg, said the stealing in his collection in California is a robbery. But stealing art is worth more than 5 percent of the cost and the reward, in ensuing reward evaluations. Art thieves don't get a penny or a small fortune, professor says, a professor says.
# Reward: 0.460965068295618
#
# Epoch 1, Sample 116
# Generated Summary: "The Wire" and "Draper" received in most Emmy nominations. Emmys history of "The Wire” came out with nod "Mad Men" - and "Damages". But some show shows, but many praised the show. One Emmy Nod in 2008 was "A" or "The Show"
# Reward: 0.4347617633779486
# Reward: 0.10546744250028883
#
# Epoch 3, Sample 799
# Generated Summary: Hillary.
# Reward: 0.09798385908729151
#
# Epoch 3, Sample 800
# Generated Summary: Canadian.
# Reward: 0.1649391127243196
#
# Epoch 3, Sample 801
# Generated Summary: Breast Cancer.
# Reward: 0.0728397281900529
#
# Epoch 3, Sample 802
# Generated Summary: Ms Burrows.
# Reward: 0.1488452790129898
#
# Epoch 3, Sample 803
# Generated Summary: Fenerbahce.
# Reward: 0.1399859877427419
#
# Epoch 3, Sample 804
# Generated Summary: Bush.
# Reward: 0.20323438610853972
#
# Epoch 3, Sample 805
# Generated Summary: Swiss.
# Reward: 0.11308658430653233
#
# Epoch 3, Sample 806
# Generated Summary: USS.
# Reward: 0.15449216567046836
#
# Epoch 3, Sample 807
# Generated Summary: Australia.
# Reward: 0.16015224004530842
#
# Epoch 3, Sample 808
# Generated Summary: McCain.
# Reward: 0.17291715179595904
#
# Epoch 3, Sample 809
# Generated Summary: Heather.
# Reward: 0.1340540575155448
#
# Epoch 3, Sample 810
# Generated Summary: Indonesia.
# Reward: 0.21234343453055293
#
# Epoch 3, Sample 811
# Generated Summary: German.
# Reward: 0.13795830007122453
#
# Epoch 3, Sample 812
# Generated Summary: California.
# Reward: -0.0005404887123940825
#
# Epoch 3, Sample 813
# Generated Summary: The spider.
# Reward: 0.17438784557230333
#
# Epoch 3, Sample 814
# Generated Summary: eBay.
# Reward: 0.1740808051671195
#
# Epoch 3, Sample 815
# Generated Summary: Rogers.
# Reward: 0.18297834534394114
#
# Epoch 3, Sample 816
# Generated Summary: Irving.
# Reward: 0.15282959687786224
#
# Epoch 3, Sample 817
# Generated Summary: Obama.
# Reward: 0.1583780984298603
#
# Epoch 3, Sample 818
# Generated Summary: Michelle.
# Reward: 0.17183579322639625
#
# Epoch 3, Sample 819
# Generated Summary: the gorillas.
# Reward: 0.240156277454773
#
# Epoch 3, Sample 820
# Generated Summary: A bomb in London.
# Reward: 0.2903625085676983
#
# Epoch 3, Sample 821
# Generated Summary: Obama.
# Reward: 0.10869743998604592
#
# Epoch 3, Sample 822
# Generated Summary: Iraq.
# Reward: 0.1266176184018453
#
# Epoch 3, Sample 823
# Generated Summary: Georgia.
# Reward: 0.11252455330832324
#
# Epoch 3, Sample 824
# Generated Summary: Uganda.
# Reward: 0.1963220637133627
#
# Epoch 3, Sample 825
# Generated Summary: Nigeria.
# Reward: 0.010849465791355161
#
# Epoch 3, Sample 826
# Generated Summary: VA.
# Reward: 0.14396712964602404
#
# Epoch 3, Sample 827
# Generated Summary: Japanese.
# Reward: 0.017040201451848536
#
# Epoch 3, Sample 828
# Generated Summary: Reuters.
# Reward: 0.2181968331336975
#
# Epoch 3, Sample 829
# Generated Summary: Sudan.
# Reward: 0.22536242862854922
#
# Epoch 3, Sample 830
# Generated Summary: The Navy.
# Reward: 0.1913991254438348
#
# Epoch 3, Sample 831
# Generated Summary: Arthur.
# Reward: 0.16239033432801564
#
# Epoch 3, Sample 832
# Generated Summary: Iraq.
# Reward: 0.15227761996283887
#
# Epoch 3, Sample 833
# Generated Summary: Guatemala.
# Reward: 0.22475946875152442
#
# Epoch 3, Sample 834
# Generated Summary: Myanmar.
# Reward: 0.15198996057070008
#
# Epoch 3, Sample 835
# Generated Summary: Banksy.
# Reward: 0.0478797064984546
#
# Epoch 3, Sample 836
# Generated Summary: The US.
# Reward: 0.11550211162006209
#
# Epoch 3, Sample 837
# Generated Summary: South Africa.
# Reward: 0.2250704645739467
#
# Epoch 3, Sample 838
# Generated Summary: Fernandez.
# Reward: 0.16440011935624466
#
# Epoch 3, Sample 839
# Generated Summary: Bush.
# Reward: 0.1866572475830714
#
# Epoch 3, Sample 840
# Generated Summary: Pakistan.
# Reward: 0.06406314986593582
#
# Epoch 3, Sample 841
# Generated Summary: Food industry.
# Reward: 0.174445316054885
#
# Epoch 3, Sample 842
# Generated Summary: Obama.
# Reward: 0.18550263627681854
#
# Epoch 3, Sample 843
# Generated Summary: Kilpatrick.
# Reward: 0.2485537873348741
#
# Epoch 3, Sample 844
# Generated Summary: Clinton.
# Reward: 0.2230415836457283
#
# Epoch 3, Sample 845
# Generated Summary: Traffic rage.
# Reward: 0.28605119509574695
#
# Epoch 3, Sample 846
# Generated Summary: Sara.
# Reward: 0.15108780809358702
#
# Epoch 3, Sample 847
# Generated Summary: Clinton.
# Reward: 0.20403971986353486
#
# Epoch 3, Sample 848
# Generated Summary: West.
# Reward: 0.14624519801785793
#
# Epoch 3, Sample 849
# Generated Summary: Obama.
# Reward: 0.19978808784725693
#
# Epoch 3, Sample 850
# Generated Summary: Iraq.
# Reward: 0.07549200665492278
#
# Epoch 3, Sample 851
# Generated Summary: Bergendorff.
# Reward: 0.17966250917268178
#
# Epoch 3, Sample 852
# Generated Summary: China.
# Reward: 0.05541123070500114
#
# Epoch 3, Sample 853
# Generated Summary: Iran.
# Reward: 0.19501552203287578
#
# Epoch 3, Sample 854
# Generated Summary: Japan.
# Reward: 0.08561444150076972
#
# Epoch 3, Sample 855
# Generated Summary: Georgia.
# Reward: 0.1694143707654914
#
# Epoch 3, Sample 856
# Generated Summary: Pakistan.
# Reward: 0.19849205348226756
#
# Epoch 3, Sample 857
# Generated Summary: The U.S. Navy.
# Reward: 0.22103219020635562
#
# Epoch 3, Sample 858
# Generated Summary: Obama.
# Reward: 0.20574370251761542
#
# Epoch 3, Sample 859
# Generated Summary: The call.
# Reward: 0.08895964296892578
#
# Epoch 3, Sample 860
# Generated Summary: Donohoo.
# Reward: 0.21645817804451728
#
# Epoch 3, Sample 861
# Generated Summary: This robot.
# Reward: 0.1323883582102625
#
# Epoch 3, Sample 862
# Generated Summary: The war.
# Reward: 0.21342208775639712
#
# Epoch 3, Sample 863
# Generated Summary: Italian.
# Reward: 0.142251188118579
#
# Epoch 3, Sample 864
# Generated Summary: A bus carrying military.
# Reward: 0.30695890011687726
#
# Epoch 3, Sample 865
# Generated Summary: Kelly.
# Reward: 0.031053841768792178
#
# Epoch 3, Sample 866
# Generated Summary: Clinton.
# Reward: 0.23710246091207773
#
# Epoch 3, Sample 867
# Generated Summary: Iraq.
# Reward: 0.15407134708022518
#
# Epoch 3, Sample 868
# Generated Summary: Tehran.
# Reward: 0.14935047515602998
#
# Epoch 3, Sample 869
# Generated Summary: Diana.
# Reward: 0.2007157943026941
#
# Epoch 3, Sample 870
# Generated Summary: Russian.
# Reward: 0.1522463935497287
#
# Epoch 3, Sample 871
# Generated Summary: Brazilian.
# Reward: 0.18250810585238714
#
# Epoch 3, Sample 872
# Generated Summary: Starbucks.
# Reward: 0.19186804129017723
#
# Epoch 3, Sample 873
# Generated Summary: Birmingham.
# Reward: 0.16488736803117005
#
# Epoch 3, Sample 874
# Generated Summary: Abrahamian.
# Reward: 0.13514686169132356
#
# Epoch 3, Sample 875
# Generated Summary: Chiquita.
# Reward: 0.14755897009138966
#
# Epoch 3, Sample 876
# Generated Summary: Bangladesh.
# Reward: 0.197776662923158
#
# Epoch 3, Sample 877
# Generated Summary: The gas.
# Reward: 0.0857298574026893
#
# Epoch 3, Sample 878
# Generated Summary: Bachner.
# Reward: 0.1323665623372915
#
# Epoch 3, Sample 879
# Generated Summary: Hurricane Gustav.
# Reward: 0.23550858653110007
#
# Epoch 3, Sample 880
# Generated Summary: Riley Ann."
# Reward: 0.12325403111200807
#
# Epoch 3, Sample 881
# Generated Summary: A census in Sudan.
# Reward: 0.37664350095787574
#
# Epoch 3, Sample 882
# Generated Summary: Khan.
# Reward: 0.18530051140558151
#
# Epoch 3, Sample 883
# Generated Summary: Oklahoma.
# Reward: 0.1730411798613412
#
# Epoch 3, Sample 884
# Generated Summary: Turkey.
# Reward: 0.16339840100361752
#
# Epoch 3, Sample 885
# Generated Summary: Brady.
# Reward: 0.23236446333746621
#
# Epoch 3, Sample 886
# Generated Summary: Roddick.
# Reward: 0.22276967545834983
#
# Epoch 3, Sample 887
# Generated Summary: Delta.
# Reward: 0.2079075816424206
#
# Epoch 3, Sample 888
# Generated Summary: Colombia.
# Reward: 0.23846005598704018
#
# Epoch 3, Sample 889
# Generated Summary: Malvo.
# Reward: 0.23428153629191434
#
# Epoch 3, Sample 890
# Generated Summary: Pakistan.
# Reward: 0.18127299928431417
#
# Epoch 3, Sample 891
# Generated Summary: Iraq.
# Reward: 0.13988903837594374
#
# Epoch 3, Sample 892
# Generated Summary: Cuba.
# Reward: 0.24959066814650913
#
# Epoch 3, Sample 893
# Generated Summary: Bradford.
# Reward: 0.1873258493261517
#
# Epoch 3, Sample 894
# Generated Summary: French.
# Reward: 0.18199403481873855
#
# Epoch 3, Sample 895
# Generated Summary: Obama.
# Reward: 0.1756375768304873
#
# Epoch 3, Sample 896
# Generated Summary: AC Milan.
# Reward: 0.23522245953159948
#
# Epoch 3, Sample 897
# Generated Summary: Clinton.
# Reward: 0.17105968846215142
#
# Epoch 3, Sample 898
# Generated Summary: The valves.
# Reward: 0.15894163719813026
#
# Epoch 3, Sample 899
# Generated Summary: Consumer Reports.
# Reward: 0.1539560148313448
#
# Epoch 3, Sample 900
# Generated Summary: Diana.
# Reward: 0.18692129342644304
#
# Epoch 3, Sample 901
# Generated Summary: Autism.
# Reward: 0.20302368568457085
#
# Epoch 3, Sample 902
# Generated Summary: Saudi.
# Reward: 0.14014741662389238
#
# Epoch 3, Sample 903
# Generated Summary: Kuwait.
# Reward: 0.22018424969799114
#
# Epoch 3, Sample 904
# Generated Summary: Dubai.
# Reward: 0.15622875891016713
#
# Epoch 3, Sample 905
# Generated Summary: Bush.
# Reward: 0.21308945373082772
#
# Epoch 3, Sample 906
# Generated Summary: Vick.
# Reward: 0.21535630631954109
#
# Epoch 3, Sample 907
# Generated Summary: His.
# Reward: 0.11216416891755128
#
# Epoch 3, Sample 908
# Generated Summary: A tornado.
# Reward: 0.1911410093227057
#
# Epoch 3, Sample 909
# Generated Summary: Seed vault.
# Reward: 0.2646268513467577
#
# Epoch 3, Sample 910
# Generated Summary: Cluster bombs.
# Reward: 0.2604248458795156
#
# Epoch 3, Sample 911
# Generated Summary: A JetBlue plane.
# Reward: 0.10656282968667088
#
# Epoch 3, Sample 912
# Generated Summary: Qatar.
# Reward: 0.2807008232343213
#
# Epoch 3, Sample 913
# Generated Summary: Colorado.
# Reward: 0.056718366229256925
#
# Epoch 3, Sample 914
# Generated Summary: The school.
# Reward: 0.09641379141340069
#
# Epoch 3, Sample 915
# Generated Summary: Transportations along the United States.
# Reward: 0.09156166911125183
#
# Epoch 3, Sample 916
# Generated Summary: France.
# Reward: 0.1636042469820679
#
# Epoch 3, Sample 917
# Generated Summary: McCain.
# Reward: 0.23605778342706185
#
# Epoch 3, Sample 918
# Generated Summary: Obama.
# Reward: 0.21611041132849879
#
# Epoch 3, Sample 919
# Generated Summary: Townsend.
# Reward: 0.24079526364302434
#
# Epoch 3, Sample 920
# Generated Summary: The boat.
# Reward: 0.15664204823182504
#
# Epoch 3, Sample 921
# Generated Summary: Singer.
# Reward: 0.14936252057076344
#
# Epoch 3, Sample 922
# Generated Summary: A girl from Las Vegas.
# Reward: 0.17055020706775864
#
# Epoch 3, Sample 923
# Generated Summary: The arms and military equipment.
# Reward: 0.15854496836399085
#
# Epoch 3, Sample 924
# Generated Summary: Japanese balloonist.
# Reward: 0.21768927250589645
#
# Epoch 3, Sample 925
# Generated Summary: Iran.
# Reward: 0.053837889549778965
#
# Epoch 3, Sample 926
# Generated Summary: A rodent.
# Reward: 0.18438855120113917
#
# Epoch 3, Sample 927
# Generated Summary: Seattle.
# Reward: 0.1695010031320971
#
# Epoch 3, Sample 928
# Generated Summary: Hurricane.
# Reward: 0.17087691684876405
#
# Epoch 3, Sample 929
# Generated Summary: Iraq.
# Reward: 0.11796108211608643
#
# Epoch 3, Sample 930
# Generated Summary: Manchester City.
# Reward: 0.2492859255242091
#
# Epoch 3, Sample 931
# Generated Summary: Somali.
# Reward: 0.10358097743988037
#
# Epoch 3, Sample 932
# Generated Summary: Saudi.
# Reward: 0.14816153453743974
#
# Epoch 3, Sample 933
# Generated Summary: Drugs.
# Reward: 0.14365530014545358
#
# Epoch 3, Sample 934
# Generated Summary: Finland.
# Reward: 0.0966212890364907
#
# Epoch 3, Sample 935
# Generated Summary: Lafave.
# Reward: 0.13629036974425265
#
# Epoch 3, Sample 936
# Generated Summary: Sheffield FC.
# Reward: 0.25414677240631794
#
# Epoch 3, Sample 937
# Generated Summary: Rafael.
# Reward: 0.160877019889427
#
# Epoch 3, Sample 938
# Generated Summary: .
# Reward: 0.022586479958365945
#
# Epoch 3, Sample 939
# Generated Summary: March.
# Reward: 0.012212322773160155
#
# Epoch 3, Sample 940
# Generated Summary: The American.
# Reward: 0.04673868729326971
#
# Epoch 3, Sample 941
# Generated Summary: Canada.
# Reward: 0.19198286879177834
#
# Epoch 3, Sample 942
# Generated Summary: Kenya.
# Reward: 0.24635912869597398
#
# Epoch 3, Sample 943
# Generated Summary: Iraq.
# Reward: 0.16645149913099078
#
# Epoch 3, Sample 944
# Generated Summary: The bomb devices.
# Reward: 0.1297822306795818
#
# Epoch 3, Sample 945
# Generated Summary: Pictures.
# Reward: 0.10586443179991187
#
# Epoch 3, Sample 946
# Generated Summary: A campus.
# Reward: 0.15054950633564512
#
# Epoch 3, Sample 947
# Generated Summary: Iraq.
# Reward: 0.1367769888856194
#
# Epoch 3, Sample 948
# Generated Summary: Alaska.
# Reward: 0.16718648656016258
#
# Epoch 3, Sample 949
# Generated Summary: France.
# Reward: 0.11752104092585412
#
# Epoch 3, Sample 950
# Generated Summary: A cop.
# Reward: 0.1909591413278788
#
# Epoch 3, Sample 951
# Generated Summary: Myanmar.
# Reward: 0.078122890968712
#
# Epoch 3, Sample 952
# Generated Summary: A newborn.
# Reward: 0.13758771470252504
#
# Epoch 3, Sample 953
# Generated Summary: Orange.
# Reward: 0.14421369972683135
#
# Epoch 3, Sample 954
# Generated Summary: German.
# Reward: 0.03555497934943751
#
# Epoch 3, Sample 955
# Generated Summary: A good book.
# Reward: 0.17450806745484004
#
# Epoch 3, Sample 956
# Generated Summary: Kosovo.
# Reward: 0.21599861204624177
#
# Epoch 3, Sample 957
# Generated Summary: Arizona.
# Reward: 0.04547249269485474
#
# Epoch 3, Sample 958
# Generated Summary: Japanese.
# Reward: 0.15328450532616644
#
# Epoch 3, Sample 959
# Generated Summary: Lauren.
# Reward: 0.1630450712808799
#
# Epoch 3, Sample 960
# Generated Summary: A letter.
# Reward: 0.045109535249717087
#
# Epoch 3, Sample 961
# Generated Summary: Carson.
# Reward: 0.17069077321716974
#
# Epoch 3, Sample 962
# Generated Summary: Two women that.
# Reward: 0.11799563074111939
#
# Epoch 3, Sample 963
# Generated Summary: Pausch.
# Reward: 0.23075744668642678
#
# Epoch 3, Sample 964
# Generated Summary: Danish.
# Reward: 0.023137834043921647
#
# Epoch 3, Sample 965
# Generated Summary: The bill.
# Reward: 0.15057172016663983
#
# Epoch 3, Sample 966
# Generated Summary: Zimbabwe.
# Reward: 0.22240507069312537
#
# Epoch 3, Sample 967
# Generated Summary: Cheathem.
# Reward: 0.034206690069507155
#
# Epoch 3, Sample 968
# Generated Summary: Iran.
# Reward: 0.19037564274860405
#
# Epoch 3, Sample 969
# Generated Summary: Benedict.
# Reward: 0.16083092675799604
#
# Epoch 3, Sample 970
# Generated Summary: Penn.
# Reward: 0.2550903048212566
#
# Epoch 3, Sample 971
# Generated Summary: Iowa.
# Reward: 0.15968504638382883
#
# Epoch 3, Sample 972
# Generated Summary: The immigration debate.
# Reward: 0.27660759190718337
#
# Epoch 3, Sample 973
# Generated Summary: bin Laden.
# Reward: 0.21948881262057537
#
# Epoch 3, Sample 974
# Generated Summary: Iraq.
# Reward: 0.12247844796914321
#
# Epoch 3, Sample 975
# Generated Summary: Derby.
# Reward: 0.1357479708251499
#
# Epoch 3, Sample 976
# Generated Summary: Blackwater.
# Reward: 0.1461385345908332
#
# Epoch 3, Sample 977
# Generated Summary: Armenia.
# Reward: 0.01689266076213435
#
# Epoch 3, Sample 978
# Generated Summary: Iraq.
# Reward: 0.08477671947972527
#
# Epoch 3, Sample 979
# Generated Summary: The fires.
# Reward: 0.2125628209114075
#
# Epoch 3, Sample 980
# Generated Summary: Valentine.
# Reward: 0.2023647008717623
#
# Epoch 3, Sample 981
# Generated Summary: Colorado.
# Reward: 0.21573576683347873
#
# Epoch 3, Sample 982
# Generated Summary: Prince.
# Reward: 0.1605759215668311
#
# Epoch 3, Sample 983
# Generated Summary: The tracksuit.
# Reward: 0.02732257066028458
#
# Epoch 3, Sample 984
# Generated Summary: Bremen.
# Reward: 0.19117401619038166
#
# Epoch 3, Sample 985
# Generated Summary: Europe.
# Reward: 0.062386778172324686
#
# Epoch 3, Sample 986
# Generated Summary: Celtic.
# Reward: 0.17451373554497396
#
# Epoch 3, Sample 987
# Generated Summary: Libya.
# Reward: 0.2720131002532111
#
# Epoch 3, Sample 988
# Generated Summary: Colombia.
# Reward: 0.13310309533085096
#
# Epoch 3, Sample 989
# Generated Summary: Clinton.
# Reward: 0.22297420798542072
#
# Epoch 3, Sample 990
# Generated Summary: Sullivan.
# Reward: 0.1627883088921192
#
# Epoch 3, Sample 991
# Generated Summary: The Death.
# Reward: 0.1781995577765446
#
# Epoch 3, Sample 992
# Generated Summary: Zimbabwe.
# Reward: 0.10407476141339257
#
# Epoch 3, Sample 993
# Generated Summary: The Sword.
# Reward: 0.0565206628804731
#
# Epoch 3, Sample 994
# Generated Summary: The zoo.
# Reward: 0.11833880055518378
#
# Epoch 3, Sample 995
# Generated Summary: Thaksin.
# Reward: 0.12104801316010325
#
# Epoch 3, Sample 996
# Generated Summary: A helicopter.
# Reward: -0.0008128915647310879
#
# Epoch 3, Sample 997
# Generated Summary: William.
# Reward: 0.14559787386801187
#
# Epoch 3, Sample 998
# Generated Summary: Hollywood.
# Reward: 0.07002044907121946
#
# Epoch 3, Sample 999
# Generated Summary: Afghanistan.
# Reward: 0.20582802809222062
#
# Epoch 3, Sample 1000
# Generated Summary: Barcelona.
# Reward: 0.16330171957327483
#
# Epoch 3 Average Reward: 0.17144965509780782
# RL Training Complete. Rewards: [0.37634366312196027, 0.167997529641126, 0.17144965509780782]
